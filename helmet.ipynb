# %%
# !pip install -q kaggle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir ~/.kaggle
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets list
# !kaggle datasets download -d andrewmvd/helmet-detection
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# ref                                                          title                                           size  lastUpdated          downloadCount  voteCount  usabilityRating
# -----------------------------------------------------------  ---------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# valakhorasani/mobile-device-usage-and-user-behavior-dataset  Mobile Device Usage and User Behavior Dataset   11KB  2024-09-28 20:21:12          15254        332  1.0
# valakhorasani/gym-members-exercise-dataset                   Gym Members Exercise Dataset                    22KB  2024-10-06 11:27:38           8257        135  1.0
# arpitsinghaiml/global-suicide-statistics                     Global Suicide Statistics                        5KB  2024-10-26 04:05:35            644         24  1.0
# ...

# %%
# !unzip helmet-detection.zip -d /content/helmet_detection/
# Out:
# Archive:  helmet-detection.zip
#   inflating: /content/helmet_detection/annotations/BikesHelmets0.xml
#   inflating: /content/helmet_detection/annotations/BikesHelmets1.xml
#   inflating: /content/helmet_detection/annotations/BikesHelmets10.xml
#   inflating: /content/helmet_detection/annotations/BikesHelmets100.xml
#   inflating: /content/helmet_detection/annotations/BikesHelmets101.xml
#   inflating: /content/helmet_detection/annotations/BikesHelmets102.xml
#   inflating: /content/helmet_detection/annotations/BikesHelmets103.xml
#   inflating: /content/helmet_detection/annotations/BikesHelmets104.xml
#   inflating: /content/helmet_detection/annotations/BikesHelmets105.xml
#   inflating: /content/helmet_detection/annotations/BikesHelmets106.xml
#   inflating: /content/helmet_detection/annotations/BikesHelmets107.xml
#   inflating: /content/helmet_detection/annotations/BikesHelmets108.xml
#   inflating: /content/helmet_detection/annotations/BikesHelmets109.xml
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="VswiFR1rz9IYH1XJXM3s")
project = rf.workspace("bike-helmets").project("bike-helmet-detection-2vdjo")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Bike-Helmet-Detection-2 in yolov8:: 100%|██████████| 7482/7482 [00:01<00:00, 6464.58it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 878.7/878.7 kB 27.3 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=../content/Bike-Helmet-Detection-2/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.25 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
